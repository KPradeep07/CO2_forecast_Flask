# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
df_ar = pd.read_excel("CO2 dataset.xlsx")
df_ar.head()
# Out:
#      Year      CO2
# 0  1800.0  0.00568
# 1  1801.0  0.00561
# 2  1802.0  0.00555
# 3  1803.0  0.00548
# 4  1804.0  0.00542

# %%
index = pd.date_range(start="1800", end="2015", freq="A-DEC")
index
# Out:
# DatetimeIndex(['1800-12-31', '1801-12-31', '1802-12-31', '1803-12-31',
#                '1804-12-31', '1805-12-31', '1806-12-31', '1807-12-31',
#                '1808-12-31', '1809-12-31',
#                ...
#                '2005-12-31', '2006-12-31', '2007-12-31', '2008-12-31',
#                '2009-12-31', '2010-12-31', '2011-12-31', '2012-12-31',
#                '2013-12-31', '2014-12-31'],
#               dtype='datetime64[ns]', length=215, freq='A-DEC')

# %%
df_ar.drop("Year", axis=1, inplace=True)

# %%
df_ar.set_index(index, inplace=True)

# %%
df_ar
# Out:
#                  CO2
# 1800-12-31   0.00568
# 1801-12-31   0.00561
# 1802-12-31   0.00555
# 1803-12-31   0.00548
# 1804-12-31   0.00542
# ...              ...
# 2010-12-31  15.60000
# 2011-12-31  15.60000
# 2012-12-31  14.80000
# 2013-12-31  14.70000
# 2014-12-31  15.10000
#
# [215 rows x 1 columns]

# %%
model_arima_final = ARIMA(df_ar, order = (10, 1, 15)).fit()
# Out:
# C:\Users\STUDENT\anaconda3\envs\co2\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
fitted = model_arima_final.predict(start = 0, end = 214)

# %%
plt.figure(figsize=(12,10))
plt.plot(df_ar, color='green', label='Train')
plt.plot(fitted, color='magenta', label='Forecast')
plt.title("Foecating by ARIMA")
plt.xlabel("year")
plt.ylabel("CO2 level")
plt.legend()
plt.show()

# %%
forecast_final = model_arima_final.predict(start=215, end = 265)
forecast_final.head()
# Out:
# 2015-12-31    14.749780
# 2016-12-31    14.568704
# 2017-12-31    14.803718
# 2018-12-31    14.280966
# 2019-12-31    14.381621
# Freq: A-DEC, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(10,8))
plt.plot(df_ar, color='green', label='train')
plt.plot(forecast_final, color='Red', label='forecast')
plt.title("Foecating by ARIMA")
plt.xlabel("year")
plt.ylabel("CO2 level")
plt.legend()
plt.show()

# %%
import pickle
file = open("CO2_Forecasting_ARIMA.pkl","wb")
pickle.dump(model_arima_final , file)
